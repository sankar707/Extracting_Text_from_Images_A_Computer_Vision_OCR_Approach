# %%
import os
import cv2
import shutil
import random
import pytesseract
try:
    from PIL import Image
except ImportError:
     import Image

import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = 'images/01.jpg'
image_path2 = 'images/05.jpg'

# %%
image_orignal=cv2.imread(image_path)
plt.imshow(image_orignal)
plt.axis("off")
plt.show()

# %%
image_path_in_jupyter=image_path
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_jupyter))
print(extractedInformation)
# Out:
# P)KA/RZD
#
# a 616 40132" rsx
#
# oP.
# g3.2008 20 (20K
#
# eo HAL
#
# OCTPOEH S
# 15.03.2017
#
# KP.
# sae 15.03.2035
#
# Al
# MOCKBA.CTAPAR BACAR. C2.)
# TEs. (485) 659 0104 @NKC*7 48S) 762 96.8

# %%
image_orignal=cv2.imread(image_path2)
plt.imshow(image_orignal)
plt.axis("off")
plt.show()

# %%
image_path_in_jupyter=image_path2
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_jupyter))
print(extractedInformation)
# Out:
# APEHQOBAH AO ..CU3K”
#
# AO .CHBHPCKAS YP OSIbHASL
# ‘SHEPPETHYECKAS KOMMAHKA™
#
# 60S4, MOCKBA, OUGMINNCKAR,S3.CTR7
#
# ‘TEM 67 (485) 795 2538, PANE +7 (485) 785 25 42
#
# P)KD/RZD
#
# — Sy =
# 636 73149 ee ..
# .ge2024 20 (20KM/4

# %%
image_path = 'images/09.jpg'
image_path2 = 'images/12.jpg'

# %%
image_orignal=cv2.imread(image_path)
plt.imshow(image_orignal)
plt.axis("off")
plt.show()

# %%
image_path_in_jupyter=image_path
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_jupyter))
print(extractedInformation)
# Out:
# 95 003 44°
#
# PL
# ° PI Pyce rpoT paHe
#
# gy sre! in y i
#
# a = =. en) eee | ee
# 5 5 = @ =| =|
# & wir = 95500344" [207 eS:

# %%
image_orignal=cv2.imread(image_path2)
plt.imshow(image_orignal)
plt.axis("off")
plt.show()

# %%
image_path_in_jupyter=image_path2
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_jupyter))
print(extractedInformation)
# Out:
# rpy3oBaa |
# , KOMMaHMA
